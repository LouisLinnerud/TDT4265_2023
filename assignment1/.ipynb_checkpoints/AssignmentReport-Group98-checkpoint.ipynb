# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %%
from IPython.display import Image
from os.path import isfile, join
from os import listdir
import glob

# %%
path_to_pictures = r'c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1'

# %%
images_locations = [join(path_to_pictures, f) for f in listdir(path_to_pictures) if isfile(join(path_to_pictures, f))]
for i, name in enumerate(images_locations):
    print(i, name)
# Out:
# 0 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\1a.png
# 1 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\1b.png
# 2 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\2b_training_and_validation_loss_no_zoom.png
# 3 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\2b_training_and_validation_loss_with_zoom.png
# 4 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\2c_training_and_validation_accuracy.png
# 5 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\2e_training_loss_with_shuffle.png
# 6 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\2e_validation_accuracy_with_shuffle.png
# 7 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\3b_training_and_validation_loss.png
# 8 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\3c_accuracy.png
# 9 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\3d_overfitting.png
# 10 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\4a_1.png
# 11 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\4a_2.png
# 12 c:\Users\tinus\OneDrive\Dokumenter\01 I&ICT V23\TDT4265\Assignment 1\4b_digits.png

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %%
display(Image(filename=images_locations[0]))

# %% [markdown]
# ## task 1b)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %%
display(Image(filename=images_locations[1]))

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2b)
# ![](task2b_binary_train_loss.png)

# %% [markdown]
# ## Task 2c)
# ![](task2b_binary_train_accuracy.png)

# %% [markdown]
# ## Task 2d)
# FILL IN ANSWER

# %% [markdown]
# ## Task 2e)
# FILL IN ANSWER
# ![](task2e_train_accuracy_shuffle_difference.png)

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Task 3b)
# ![](task3b_softmax_train_loss.png)

# %% [markdown]
# ## Task 3c)
# ![](task3b_softmax_train_accuracy.png)

# %% [markdown]
# ## Task 3d)
# FILL IN ANSWER

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# Fill in image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# ## Task 4b)
# FILL IN ANSWER
#
# ![](task4b_softmax_weight.png)

# %% [markdown]
# ## Task 4c)
# FILL IN ANSWER
#
# ![](task4c_l2_reg_accuracy.png)

# %% [markdown]
# ## Task 4d)
# ![](task4d_l2_reg_norms.png)

# %% [markdown]
# ## Task 4e)
# FILL IN ANSWER
