# %% [markdown]
# # Task 3

# %%
import pathlib
import matplotlib.pyplot as plt
import utils
from torch import nn
from dataloaders import load_cifar10
from trainer import Trainer, compute_loss_and_accuracy

# %%
class Task3Model(nn.Module):

    def __init__(self, image_channels, num_classes):
        
        super().__init__()
        
        self.num_classes = num_classes
        
        # Define the convolutional layers
        self.feature_extractor = nn.Sequential(
             
            nn.Conv2d(
                in_channels=image_channels,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding=0
            ),
            nn.LeakyReLU(.2),
            nn.BatchNorm2d(16),
            
            nn.Conv2d(
                in_channels=16,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=0
            ),
            nn.LeakyReLU(.2),
            nn.BatchNorm2d(32),

            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.LeakyReLU(.2),

            nn.MaxPool2d(
                [2,2],
                stride=2
            ), 
            nn.BatchNorm2d(64),
             
            nn.Conv2d(
                in_channels=64,
                out_channels=128,
                kernel_size=3,
                stride=1,
                padding=0
            ),
            nn.LeakyReLU(.2),
            nn.BatchNorm2d(128),

            nn.Conv2d(
                in_channels=128,
                out_channels=256,
                kernel_size=3,
                stride=1,
                padding=0
            ),
            nn.LeakyReLU(.2),
            nn.BatchNorm2d(256),

            nn.Conv2d(
                in_channels=256,
                out_channels=512,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.LeakyReLU(.2),
            
            

            nn.MaxPool2d(
                [2,2],
                stride=2
            ),
            nn.BatchNorm2d(512)
        ) 

   
        self.num_output_features = 5*5*512
        self.num_hidden_units = 256
   
        # __ Layer 4 __
        self.classifier = nn.Sequential(
            #Fully connected 64 
            nn.Linear(self.num_output_features, self.num_hidden_units),
            #Activation ReLU
            nn.LeakyReLU(),
            #Fully connected 10
            nn.Linear(self.num_hidden_units, num_classes)
        )

    def forward(self, x):
        
        batch_size = x.shape[0]
        x = self.feature_extractor(x)
        x = x.view(-1,self.num_output_features) # view(batch_size,-1) instead??
        x = self.classifier(x)
        
        out = x

        expected_shape = (batch_size, self.num_classes)
        
        assert out.shape == (batch_size, self.num_classes),\
            f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
def create_plots(trainer: Trainer, name: str):
    plot_path = pathlib.Path("plots")
    plot_path.mkdir(exist_ok=True)
    # Save plots and show them
    plt.figure(figsize=(20, 8))
    plt.subplot(1, 2, 1)
    plt.grid()
    plt.title("Cross Entropy Loss")
    utils.plot_loss(trainer.train_history["loss"], label="Training loss", npoints_to_average=10)
    utils.plot_loss(trainer.validation_history["loss"], label="Validation loss")
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.title("Accuracy")
    plt.grid()
    utils.plot_loss(trainer.validation_history["accuracy"], label="Validation Accuracy")
    plt.legend()
    plt.savefig(plot_path.joinpath(f"{name}_plot.png"))
    plt.show()

# %%
utils.set_seed(0)
epochs = 10
batch_size = 64
learning_rate = 15e-3
early_stop_count = 4
dataloaders = load_cifar10(batch_size)
model = Task3Model(image_channels=3, num_classes=10)
optimizer = "sgd"
trainer = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model,
    dataloaders,
    optimizer
)
trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Task3Model(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): MaxPool2d(kernel_size=[2, 2], stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.2)
#     (12): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (14): LeakyReLU(negative_slope=0.2)
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): LeakyReLU(negative_slope=0.2)
#     (18): MaxPool2d(kernel_size=[2, 2], stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=12800, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=256, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 72.06, Global step:    351, Validation Loss: 1.10, Validation Accuracy: 0.607
# Epoch: 0, Batches per seconds: 53.82, Global step:    702, Validation Loss: 0.93, Validation Accuracy: 0.669
# Epoch: 1, Batches per seconds: 49.09, Global step:   1053, Validation Loss: 0.86, Validation Accuracy: 0.700
# Epoch: 1, Batches per seconds: 47.40, Global step:   1404, Validation Loss: 0.76, Validation Accuracy: 0.728
# Epoch: 2, Batches per seconds: 46.27, Global step:   1755, Validation Loss: 0.76, Validation Accuracy: 0.729
# Epoch: 2, Batches per seconds: 47.44, Global step:   2106, Validation Loss: 0.72, Validation Accuracy: 0.750
# Epoch: 3, Batches per seconds: 46.55, Global step:   2457, Validation Loss: 0.68, Validation Accuracy: 0.762
# Epoch: 3, Batches per seconds: 46.04, Global step:   2808, Validation Loss: 0.66, Validation Accuracy: 0.767
# Epoch: 4, Batches per seconds: 45.57, Global step:   3159, Validation Loss: 0.64, Validation Accuracy: 0.769
# Epoch: 4, Batches per seconds: 45.22, Global step:   3510, Validation Loss: 0.65, Validation Accuracy: 0.769
# Epoch: 5, Batches per seconds: 45.82, Global step:   3861, Validation Loss: 0.63, Validation Accuracy: 0.777
# Epoch: 5, Batches per seconds: 45.52, Global step:   4212, Validation Loss: 0.61, Validation Accuracy: 0.792
# Epoch: 6, Batches per seconds: 45.20, Global step:   4563, Validation Loss: 0.59, Validation Accuracy: 0.794
# Epoch: 6, Batches per seconds: 44.98, Global step:   4914, Validation Loss: 0.58, Validation Accuracy: 0.795
# Epoch: 7, Batches per seconds: 44.72, Global step:   5265, Validation Loss: 0.57, Validation Accuracy: 0.802
# Epoch: 7, Batches per seconds: 44.60, Global step:   5616, Validation Loss: 0.57, Validation Accuracy: 0.803
# Epoch: 8, Batches per seconds: 44.97, Global step:   5967, Validation Loss: 0.54, Validation Accuracy: 0.814
# Epoch: 8, Batches per seconds: 44.81, Global step:   6318, Validation Loss: 0.58, Validation Accuracy: 0.792
# Epoch: 9, Batches per seconds: 45.15, Global step:   6669, Validation Loss: 0.57, Validation Accuracy: 0.803
# Epoch: 9, Batches per seconds: 45.51, Global step:   7020, Validation Loss: 0.54, Validation Accuracy: 0.807
# Early stop criteria met
# Early stopping.

# %%
create_plots(trainer, "task3")

# %%
training_loss, training_accuracy = compute_loss_and_accuracy(trainer.dataloader_train, trainer.model, trainer.loss_criterion)
validation_loss, validation_accuracy = compute_loss_and_accuracy(trainer.dataloader_val, trainer.model, trainer.loss_criterion)
test_loss, test_accuracy = compute_loss_and_accuracy(trainer.dataloader_test, trainer.model, trainer.loss_criterion)
print(f"  Training: Accuracy: {training_accuracy}, Loss: {training_loss}")
print(f"Validation: Accuracy: {validation_accuracy}, Loss: {validation_loss}")
print(f"      Test: Accuracy: {test_accuracy}, Loss: {test_loss}")
# Out:
#   Training: Accuracy: 0.868732213973999, Loss: 0.40588685870170593
# Validation: Accuracy: 0.8117088675498962, Loss: 0.5419992804527283
#       Test: Accuracy: 0.8140923976898193, Loss: 0.5470222234725952
